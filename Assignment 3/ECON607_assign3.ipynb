# %% [markdown]
# # Import Libraries

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize.treebank import TreebankWordDetokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer

import spacy

import pandas as pd

from wordcloud import WordCloud

# %% [markdown]
# ## Create a function to calculate the Jaccard Similarity

# %%
def jaccardSimilarity(doc_1, doc_2):
    words_doc1 = set(doc_1.lower().split())
    words_doc2 = set(doc_2.lower().split())
    print(doc_1)
    print(doc_2)
    print(words_doc1)
    print(words_doc2)
    #List the unique words in a document

    intersection = words_doc1.intersection(words_doc2)
    #Find the intersection of words in doc_1 and doc_2

    union = words_doc1.union(words_doc2)
    #Find the union of words in doc_1 and doc_2

    return float(len(intersection)/len(union))
    #Calculate Jaccard Similarity score
    #using length of intersection set divided by length of union set

# %% [markdown]
# ## Create a function to calculate the Semantic Similarity Score

# %%
def semanticSimilarity(doc_1, doc_2):
    spc = spacy.load('en_core_web_lg')
    spacyDoc_1 = spc(doc_1)
    spacyDoc_2 = spc(doc_2)
    return spacyDoc_1.similarity(spacyDoc_2)

# %% [markdown]
# ## Create a function for Sentiment Analysis

# %%
def sentimentAnalysis(doc):
    sia = SentimentIntensityAnalyzer()
    sentiment = sia.polarity_scores(doc)
    return sentiment

# %% [markdown]
# ## Create function for text cleaning

# %%
nltk.download('vader_lexicon')
nltk.download('stopwords')
nltk.download('wordnet')

def cleanText(text):
    tokenizer = RegexpTokenizer(r'\w+')
    allTokens = tokenizer.tokenize(text)
    #Removes puncuation while tokenizing

    tokens = [token for token in allTokens if token not in stopwords.words('English')]
    #Removes the stop words

    tokens = [token.lower() for token in tokens]
    #Convert tokens to lowercase

    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    #Lemmatizes the tokens

    text = ''
    for token in tokens:
        text = text + token + ' '
    return text
    # Create a text string from the token list
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/andrew/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/andrew/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/andrew/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Create the functions to Load and Clean text

# %%
def loadText(fileName):
    f = open(fileName, 'r', encoding='utf-8')
    text = f.read()
    return text

def loadCleanText(fileName):
    text = loadText(fileName)
    return cleanText(text)

article_2 = loadCleanText('/Users/andrew/Downloads/UW courses/ECON 607/Assignment 3/badwords.txt')
commentsArticle_2 = loadCleanText('CommentsA2.txt')
#Loads the data

print("Jaccard: Article 2 vs Article 2 comments", jaccardSimilarity(article_2, commentsArticle_2))
#performs the Jaccard similarity calculation

print("Semantic: Article 2 vs Article 2 comments", semanticSimilarity(article_2, commentsArticle_2))
#performs the Semantic similarity calculation

print("Article 2", sentimentAnalysis(article_2))
print(type(sentimentAnalysis(article_2)))
#performs the Semantic Intensity calculation
#prints the type of the semantic calculation

comments = loadText('commentsA2.txt').splitlines()
for comment in comments:
    comment = cleanText(comment)
    s = sentimentAnalysis(comment)
    print(comment + ',', s["compound"])
# Out:
# bad i hate fuck shit i hate everything everything suck i fucking hate evertything i sad i cant believe stupid idiotic
# this article tell system work i closer understanding become ash let u decompose like fruit vegetable compost pile i want supportive i need detail 100 behind i care but like normal burial cremation cost borne person want composted state bill aubuchon i funeral director we pleasure presentation katrina price question asked answered bill aubuchon it would bit direct cremation way le burial the bill passed i seen article suggesting cost 5500 i would love grow plant food gramma dogmy ex not sure i feel overall doesn happen anyway nichole welp that one way dispose body do think human remains would left compost saying thats bad would use compost fertilize cemetery marcelle baldwin give source number i assume got 4 year old new york time article we see i hope right guess least double figure good politics state may bee progressive national stage it freak little i lifelong liberal lacey sutton love much thanks info tryna pay much if dying make sure eat bunch seed cut middleman human humus so mean body fertilizer whatever grows longer vegan doe make u way cannibal just throw grandma compost heap yard waste banana peel jan van liew um nope darrell eugenio tax choose pay poor job creator survive you voted interloper beware wish cremation way go ash ash dust dust joslin jane yes i want worm food longer corpse exist opportunity become museum exhibit shara robert somehow i afraid i know it fear buried alive get that disgusting happen time we gonna end lot caffeinated plant why stop soylentgreen it people i came post soylent green comment took forever reading find post i think governator first one fertilize peyote smoking do call seattle public utility ahead time arrange wife chuck green bin mark gendron sure charge extra num num cabbage made uncle mike help remember movie soylent green soylen green people add whole new dimension grandma tomato composting much work i rather frank way i want dead uncle wilbur aunt flora back yard it still expensive though while great idea peon i shall still move forward plan interment pyramid oh boy could possibly go wrong our governor worst heather cole he absolute moron you kind thats wrong many level how tackling drug use homeless problem street falling apart sign stupid bill dear loved one please soylent green people soylent green is people soylent green maybe soylent green soylent green next that disgusting soylent green coming store near how creepy amp appalling plain wrong fanfuckingtastic barf little mouth stupidest idea ever wtf wrong wa it still going cost arm leg soylen green people soylen green people cremation want ash dpnt want mud pie rather memorial day remember person soul departed omg who person of course i know i cannot believe like signing reproductive parity if know look i doubt people state even aware passed legislature jules villarreal chingow soilent green next soylent green leeann hemmingson sievers exactly enyaj nesroht i saying joke wtf freaky enyaj nesroht still scary cemetary backyard yikes carmen sipesrachel benz costenbaderdemian hardaker bill brower man we enough competition why move lol wtf cremate first i haunt ryan this lmao this sickening thing i ever seen life omg kidding fake totally fake should releasing drug back environment most elderly many prescription what hell wrong people not sure i like idea what disease infection barbaric just one step away canabalism which slipped till discovered i audra r mccoy careful one get some scam need spore area buried audra r mccoy the field testing show difference body buried without suit still charging hundred thousand dollar product eek so i tree http www youtube com watch v 0rtu1va dnm if wanna get fancy ash mixed cement create reef dropped ocean help dying reef return cool concept http www cremation com cremation eternal reef and smell good yayyyyy essence recycling another win interment industry i consider win allowed dig hole plant tree body you might able many place do allow private internment given right paperwork when science d ...
# {'bad', 'hate', 'everything', 'stupid', 'i', 'idiotic', 'evertything', 'fucking', 'shit', 'cant', 'believe', 'suck', 'fuck', 'sad'}
# {'0rtu1va', 'able', 'face', 'fat', 'mccoy', 'yikes', 'hospital', 'see', 'locality', 'assuredly', 'heck', 'interment', 'thrilled', 'dignified', 'might', 'madison', 'toxin', 'pickled', 'plan', 'highly', 'decision', 'your', 'century', 'using', '6', 'hah', 'got', 'soilent', 'sadder', 'visability', '2003', 'would', 'dollar', 'nathan', 'longer', 'contract', 'saying', 'make', 'heather', 'humus', 'left', 'fruit', 'dream', 'store', 'archaeologist', 'hydrolosis', 'update', 'said', 'pinging', 'rij8r4jk_u0cu6mltasnsrhfdxfq1wef9gq3nm5wwexpyyc4fc6cowu', 'whole', 'many', 'faster', 'dpnt', 'pan', 'david', 'rational', 'conventional', 'marie', 'word', 'pnw', 'vault', 'http', 'top', 'recompose', 'new', 'shara', 'homeless', 'came', 'gendron', 'casket', 'streamlining', 'woman', 'naw', 'feel', 'testament', 'composted', 'read', 'robert', 'lifelong', 'lol', 'jvd4qiv6r', 'peon', 'departed', 'washington', 'significantly', 'dairy', 'itl', 'cremate', 'jackie', 'composting', 'tell', 'oil', 'eye', 'standardize', 'amazing', 'instead', 'carver', 'sutton', 'direct', 'jane', 'cole', 'arrange', 'hole', 'negative', 'dioxide', 'orderofthegooddeath', 'know', 'dnm', 'chance', 'bye', 'hawkins', 'cc', 'normal', 'tree', 'everyone', 'hartwell', 'kale', 'when', 'jill', 'found', 'movie', 'turn', 'something', 'contact', 'pound', 'drippngs', 'tomato', 'offer', 'competition', 'okay', 'crazy', '100', 'environment', 'testing', 'going', 'advance', 'temporary', 'dusty', 'vegan', 'mark', 'nichole', 'paying', 'ing', 'decompose', 'hailey', 'soul', 'become', 'anymore', 'transition', 'shape', 'could', 'leeann', 'come', 'hope', 'good', 'little', 'california', 'keth', 'say', 'million', 'praise', 'pot', 'element', 'year', 'kind', 'length', 'really', 'manager', 'underground', 'inventor', 'leading', 'barbaric', 'support', 'break', 'civilized', 'look', 'remember', 'overall', 'fascinating', 'rather', 'convert', 'bacteria', 'corps', 'shredder', 'eternal', 'caffeinated', 'time', 'scam', 'le', 'commute', 'carmen', 'area', 'possible', 'manually', 'sustainable', 'becoming', 'call', 'burying', 'water', 'added', 'last', 'since', 'etc', 'more', 'cemetery', 'recycling', 'aware', 'old', 'ready', 'spore', 'westad', 'extravagance', 'innovative', 'background', 'attempt', 'aunt', 'almost', 'either', 'great', 'ex', 'involve', 'beware', 'go', 'win', 'charging', 'perfect', 'animal', 'freeman', 'freak', 'wonderful', 'we', 'excited', 'expensive', 'cow', 'care', 'render', 'return', 'service', 'part', 'discussed', 'carbon', 'fit', 'passing', 'five', 'daze', 'sweet', 'thelivingurn', 'retort', 'competitive', 'bone', 'cost', 'financial', 'helland', 'pyramid', 'too', 'toxic', 'blown', 'changed', 'favor', 'correct', 'passed', 'west', 'resting', 'wasting', 'camp', 'bill', 'concept', 'holding', 'topped', 'very', 'videosher', 'slurry', 'soil', 'bulk', 'matter', 'there', 'right', 'eat', 'gonna', 'paid', 'interloper', 'why', 'family', 'jules', 'comment', 'e', 'sky', 'around', 'opening', 'paper', 'upholstered', 'choice', 'uncle', 'lot', 'available', 'disease', 'a', 'popular', 'ahead', 'find', 'stable', 'play', 'europe', 'day', 'which', 'direction', 'for', 'hardaker', 'continue', 'website', 'another', 'property', 'earth', 'course', 'seriousness', 'price', 'horse', 'add', 'doe', 'who', 'fossil', 'number', 'forensic', 'coming', 'nate', 'per', 'wrote', 'learn', 'releasing', 'bin', 'uncomfortable', 'maybe', 'site', 'usually', 'pie', 'mean', 'disposition', 'stone', 'thank', 'worm', 'delay', 'someday', 'cate', 'www', 'especially', 'toombs', 'presentation', 'voted', 'done', 'preservation', 'wife', 'text', 'surface', 'cabbage', 'favorite', 'everything', 'this', 'put', 'resolution', 'always', 'near', 'mother', 'eternity', 'notice', 'our', 'experience', 'others', 'attribute', 'interesting', 'subject', 'cremated', 'next', 'chemical', 'faq', 'restriction', 'dear', 'predatory', 'work', 'seems', 'fb', 'claim', 'boy', 'drain', 'amazon', 'minimal', 'existing', 'any', 'returning', 'emits', 'ash', 'happy', 'benz', 'primarily', 'smoke', 'fi ...
# Jaccard: Article 2 vs Article 2 comments 0.004612546125461255
# Semantic: Article 2 vs Article 2 comments 0.5899797774043946
# Article 2 {'neg': 0.705, 'neu': 0.151, 'pos': 0.144, 'compound': -0.9728}
# <class 'dict'>
# this article tell system work i closer understanding become ash let u decompose like fruit vegetable compost pile i want supportive i need detail 100 behind , 0.6124
# i care , 0.4939
# but like normal burial cremation cost borne person want composted state , 0.5719
# bill aubuchon i funeral director we pleasure presentation katrina price question asked answered , 0.296
# bill aubuchon it would bit direct cremation way le burial , 0.0
# the bill passed i seen article suggesting cost 5500 , 0.0
# i would love grow plant food gramma dogmy ex not sure i feel overall , 0.5003
# doesn happen anyway , 0.0
# nichole welp that one way dispose body , 0.0
# do think human remains would left compost saying , 0.0
# thats bad , -0.5423
# would use compost fertilize cemetery , 0.0
# marcelle baldwin give source number i assume got 4 year old new york time article we see i hope right guess least double figure , 0.4939
# good politics state may bee progressive national stage it freak little i lifelong liberal , 0.0
# lacey sutton love much , 0.6369
# thanks info tryna pay much , 0.3612
# if dying make sure eat bunch seed cut middleman , 0.0516
# human humus , 0.0
# so mean body fertilizer whatever grows longer vegan doe make u way cannibal , 0.0
# just throw grandma compost heap yard waste banana peel , -0.4215
# jan van liew um nope , 0.0
# darrell eugenio tax choose pay poor job creator survive you voted interloper beware wish , -0.2023
# cremation way go ash ash dust dust , 0.0
# joslin jane yes i want worm food longer corpse exist opportunity become museum exhibit , 0.2732
# shara robert somehow i afraid i know it fear buried alive get , -0.1531
# that disgusting happen time , -0.5267
# we gonna end lot caffeinated plant , 0.0
# why stop soylentgreen , -0.296
# it people , 0.0
# i came post soylent green comment took forever reading find post , 0.0
# i think governator first one fertilize peyote smoking , 0.0
# do call seattle public utility ahead time arrange wife chuck green bin , 0.0
# mark gendron sure charge extra , 0.3182
# num num cabbage made uncle mike help , 0.4019
# remember movie soylent green , 0.0
# soylen green people , 0.0
# add whole new dimension grandma tomato , 0.0
# composting much work i rather frank way , 0.0
# i want dead uncle wilbur aunt flora back yard , -0.6124
# it still expensive though , 0.0
# while great idea peon i shall still move forward plan interment pyramid , 0.6249
# oh boy could possibly go wrong , -0.4767
# our governor worst , -0.6249
# heather cole he absolute moron you kind , 0.0516
# thats wrong many level , -0.4767
# how tackling drug use homeless problem street falling apart sign stupid bill , -0.7717
# dear loved one please , 0.8316
# soylent green people , 0.0
# soylent green is people , 0.0
# soylent green maybe , 0.0
# soylent green , 0.0
# soylent green next , 0.0
# that disgusting , -0.5267
# soylent green coming store near , 0.0
# how creepy amp appalling , -0.3612
# plain wrong , -0.4767
# fanfuckingtastic , 0.0
# barf little mouth , 0.0
# stupidest idea ever , -0.5267
# wtf wrong wa , -0.7845
# it still going cost arm leg , 0.0
# soylen green people , 0.0
# soylen green people , 0.0
# cremation want ash dpnt want mud pie rather memorial day remember person soul departed , 0.1531
# omg who person of course i know i cannot believe like signing reproductive parity if know look i doubt people state even aware passed legislature , -0.5588
# jules villarreal chingow , 0.0
# soilent green , 0.0
# next soylent green , 0.0
# leeann hemmingson sievers exactly , 0.0
# enyaj nesroht i saying joke , 0.296
# wtf , -0.5859
# freaky , -0.3612
# enyaj nesroht still scary cemetary backyard yikes carmen sipesrachel benz costenbaderdemian hardaker , -0.4939
# bill brower man we enough competition , 0.0
# why move lol , 0.4215
# wtf , -0.5859
# cremate first i haunt , -0.4019
# ryan this lmao , 0.5994
# this sickening thing i ever seen life omg kidding fake totally fake , -0.8481
# should releasing drug back environment most elderly many prescription , 0.0
# what hell wrong people , -0.8271
# not sure i like idea what disease infection , -0.4717
# barbaric just one step away canabalism which slipped till discovered , 0.0
# i , 0.0
# audra r mccoy careful one get some scam need spore area buried , -0.4767
# audra r mccoy the field testing show difference body buried without suit still charging hundred thousand dollar product eek , 0.0
# so i tree , 0.0
# http www youtube com watch v 0rtu1va dnm , 0.0
# if wanna get fancy ash mixed cement create reef dropped ocean help dying reef return cool concept http www cremation com cremation eternal reef , 0.7269
# and smell good , 0.4404
# yayyyyy , 0.0
# essence recycling , 0.0
# another win interment industry i consider win allowed dig hole plant tree body , 0.8225
# you might able many place do allow private internment given right paperwork , 0.2263
# when science done way body i want whatever left composted hopefully time i need human composting legal local service , 0.5423
# go recompose website they explain process http www recompose life faq , 0.0
# http recompose life model faq , 0.0
# fascinating i cremation process good environment either i need research well this opening topic needed discussed i glad article brought light important information , 0.9062
# awesome i always said i like forgo casket fertilizer the earth perfect attribute planet brought life i think fair i give back i i using anymore , 0.9118
# good bye mega billion dollar funeral industry , 0.1027
# i always imagined dying tree leaning trunk found one left element recomposting seems , 0.0
# excellent idea i love seattle best city world , 0.9201
# a someone high chance needing next five year i favor spread throughout seattle favorite city perhaps i think end life , 0.7717
# this would choice hope pass , 0.4404
# cate callahan need governor signature , 0.0
# this first choice i hope bill pass i , 0.4404
# this exactly human remains all u started dust body replenish mother earth , 0.0
# mushroom suit burial remove year rx contamination creates clean compost interesting ted talk , 0.7579
# i learned water cremation alkaline hydrolosis last summer dog passed away i took place west seattle i composted though there bone ash left i took home i ready let go , 0.3612
# marcie paradis wa resting water aquamation they amazing , 0.5859
# aj hawkins yes they wonderful , 0.7506
# i told kid want sustain tree beautiful , 0.6369
# eco transition assist passed check fb , 0.0
# i still holding tibetan sky burial feed vulture eagle , -0.4588
# i i want feed local wildlife i want go coyote critter oklahoma , 0.1531
# nathan brookshire cremation highly negative impact earth why would body burning better returning earth soil under bill aquamated still become ash way water instead fire , -0.5413
# look capuchini burial monk century bone seem remain intact though , 0.2023
# i want cremated primarily i claustrophobic imagine box eternity i like composting long i box however ash think spend eternity ever choose scattered , 0.4215
# jill eshenbaugh still scattered anywhere just rich soil instead mineral , 0.5574
# a long involve box length time sound like good plan , 0.6597
# it ok jill you dead even notice care , 0.0258
# anything aside embalming box never decompose , 0.0
# washington state new california so cool , 0.4572
# i wanna be composted so bad i excited , -0.4239
# sweet i give back instead wasting plot land , 0.0772
# this awesome we simply cannot continue use land bury body cement crypt do something positive environment we future generation think i think everyone try leave earth little bit better first entered , 0.8785
# not mention embalming chemical , 0.0
# i one looking forward becoming flesh slurry benefit well i guess i care i dead , 0.4588
# human meat general make good compost definitely step right direction the crazy industry around unsuccessful preservation human remains merely render toxic predatory financial drain people usually shape make rational decision instead guilted extravagance for someone dead my plan cremated placed sound if family want handle i like back ferry commute hour death inconvenience many people possible if family handle leave corpse unclaimed seattle area hospital i end sound anyway a great series ask a mortician caitlin doughty the order the good death http www youtube com user orderofthegooddeath videosher book smoke get in your eye excellent read legality reality surrounding death death care u industry established around http www amazon com ref dbs_a_def_rwt_bibl_vppi_i0 , -0.8481
# my experience working assistant forensic anthropologist archaeologist someone helped family others navigate system trust embalming delay inevitable month want sealed casket paying hardwood fully upholstered death cabinet scam cremation 800 really should le use cardboard casket almost never burn actual casket pay since fit well retort metal hardware damage firebrick surface mess temperature time cremation well retrieval cremains what can plan literally inevitable death one certainty life lot researched done paid year advance keeping cost low streamlining thing family it morbid plan thing family uncomfortable tell thinking want remove uncertainty whole process time need stress inform own your remains not hospital not whatever funeral service hospital contract any attempt bluff claim illegal loved one transferred another le expensive facility even take temporary possession body lie do research law area location time limit internment restriction around transporting uncremated human remains law first place may locality even still allow internment private property correct paperwork and especially pnw green option i happy one added list , -0.9161
# if properly treated meat bone even dairy work well compost the composting service use allows along stone fruit pit etc the kind thing throw pan drippngs oil fat bulk they use industrial shredder manually break everything put composting heap , 0.6705
# this bill exactly washington need we two greenest death care option available addition many green burial cemetery it huge victory , 0.1531
# human would easier compost large animal e horse cow etc look hot composting livestock composting biological process aerobic microorganism bacteria fungi convert raw organic waste stable nutrient rich organic matter also recommend thorough reading website it changed mind cremation cremation popular choice burn fossil fuel emits 600 million pound carbon dioxide atmosphere annually â equivalent 70000 car driving road year in word last thing u earth poison http bit ly 2is3x7qhttps www recompose life , 0.8834
# let face box topped flower organ play background much sadder , -0.25
# nate dwyer see thing i soon update burial demand becoming tree , -0.128
# so thrilled option embalming burial cremation negative effect environment , -0.1298
# beat hell burying body concrete vault sane reason ever , -0.6808
# mary roach wrote subject year ago 2003 book stiff make convincing argument if support concept cost come minimal amount le cremation , 0.4404
# dennis carver love book , 0.6369
# dennis carver great book actually funny place , 0.7906
# kathleen deboer favorite chapter site corps decompose science , 0.4588
# the seattle time word cost might might compare conventional option cremation burial still i love idea , 0.6369
# bill aubuchon 2500 , 0.0
# mary park perhaps cost borne person afford composted hopefully offer competitive pricing conventional option great idea , 0.8176
# from earlier article past 6 month cost composting would significantly cheaper , 0.0
# david overman cheaper perhaps cheaper full blown burial almost assuredly much expensive conventional cremation still i could afford i would choose , 0.3197
# marcelle baldwin opinion well worth , 0.4588
# would love know body nurturing earth , 0.802
# another one podlodowski add list praise state , 0.5574
# i thought homeless camp contributing human composting seriousness would good change maybe use existing cemetery shelter , 0.4019
# i rather remains end part nature helping living thing grow chemically pickled toxin put expensive hermetically sealed box http www thelivingurn com page tree zip code , 0.296
# http www thelivingurn com page tree zip code gclid eaiaiqobchmih_vs jvd4qiv6r tbh27wgbxeaayasaaegiqtvd_bwe fbclid iwar0 rij8r4jk_u0cu6mltasnsrhfdxfq1wef9gq3nm5wwexpyyc4fc6cowu , 0.0
# worst compost ever full pesticide medication process food chemical but beat heck burying burning , -0.3716
# naw im holding sky burial , 0.0
# i would totally i die , -0.6361
# please someone standardize tree burial i need one , 0.3182
# just compost kale , 0.0
# good come earth give back earth die , -0.25
# you mean actually allow people decompose like intended get outta , 0.5267
# ima tree , 0.0
# totally , 0.0
# plant tree in me , 0.0
# i would love grow tree , 0.6369
# it time , 0.0
# good direction , 0.4404
# burial sea effect , 0.0
# sound good , 0.4404
# please i want , 0.3818
# hummm i like , 0.3612
# no problem im , -0.5994
# more sustainable option please make sure get wish paper a sacred passing , 0.7624
# i already set buried natural cemetery they wrap shroud throw hole plant tree top , 0.5106
# amanda neeser lol i ready my general manager actually working legislature , 0.6486
# human remains long composted underground , 0.0
# dude use body soil pot plant like high rhiannon kettenbauerhttps youtu d7g3ruorerc , 0.3612
# chansodany daisy keth sodalin kong time go use garden , 0.0
# sign vicbodhi berachel vulk , 0.0
# kristin helland i , 0.0
# too cool , 0.3182
# do , 0.0
# great news , 0.6249
# yay , 0.5267
# yes please , 0.6124
# very cool , 0.3804
# sign , 0.0
# cool i , 0.3182
# doing , 0.0
# erin lynn sattler one reason move , 0.0
# sign , 0.0
# michelle dawson freaky learn science work , -0.3612
# shae garcia i following woman leading innovative change now need governor sign resolution , 0.4404
# yes , 0.4019
# yay , 0.5267
# amber hah i gonna without law anyway , 0.0
# kate silbaugh turn may also cheaper cremation , 0.0
# amber toombs freeman last testament say cremation i may reconsider lol i may make someone lawn even greener vegetable garden grow even faster , 0.6705
# why thing already take law allow so weird , -0.0878
# amber westad thank gawd my dream coming true , 0.743
# madison make sunflower please , 0.3182
# you going garden someday mom jackie gauvin , 0.0
# hailey callahan lisa marie juan i just saying , 0.0
# trent hodson thanks pinging per previous text like body pile cc ing ani visability , 0.6597
# dusty brown day but cool , 0.4497
# what sickening nature i hoping year , -0.1531
# terri stewart if learn process actually dignified well better earth recomposition aquamation fear second choice body i glad i able right disposition want it okay , 0.8481
# and i contact katrina inventor want bring technology uk unless something else crop first , 0.0772
# oliviaaddie finally , 0.0
# marc hartwell yes , 0.4019
# like old daze got civilized back using wooden box casket , 0.2023
# kylee date pass itl finally legal turned tree die , -0.5267
# jacob gloss yayty , 0.0
# jacob gloss , 0.0
# ember elli well one signature away legal which would awesome currently youd corpse sent europe get something like done , 0.6705

# %% [markdown]
# ## Cooccurance script

# %%
def Preprocessing(corpus):
    # Convert corpus (lines of comments) to an array of comments
    documentText = []
    corpus = corpus.splitlines()
    for row in corpus:
        documentText.append(row)      
    return documentText

# %%
def GenerateMatrix(cleanData, fileName):
    # sklearn countvectorizer
    from sklearn.feature_extraction.text import CountVectorizer
    # Convert a collection of text documents to a matrix of token counts
    cv = CountVectorizer(ngram_range=(1,1), stop_words = 'english', max_features=20)
    # matrix of token counts
    X = cv.fit_transform(cleanData)
    Xc = (X.T * X) # matrix manipulation
    Xc.setdiag(0) # set the diagonals to be zeroes as it's pointless to be 1
    names = cv.get_feature_names_out() # This are the entity names (i.e. keywords)
    df = pd.DataFrame(data = Xc.toarray(), columns = names, index = names)
    #print(df)
    print(fileName)
    df.to_csv(fileName)

# %%
def ProcessCorpus():
    fileName = "positiveComments.csv"
    with open (fileName, "r", encoding='unicode_escape') as myfile:
        data = myfile.read()
        cleanData = Preprocessing(data)
        GenerateMatrix(cleanData, "PositiveCommentsMatrix.csv")

    fileName = "negativeComments.csv"
    with open (fileName, "r", encoding='unicode_escape') as myfile:
        data = myfile.read()
        cleanData = Preprocessing(data)
        GenerateMatrix(cleanData, "NegativeCommentsMatrix.csv")

# %%
ProcessCorpus()
# Out:
# PositiveCommentsMatrix.csv
# NegativeCommentsMatrix.csv
